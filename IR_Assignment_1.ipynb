# %% [markdown]
# <a href="https://colab.research.google.com/github/arya-snh/CSE508_Winter2024_A1_2020498/blob/main/IR_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import re
import pickle
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from string import punctuation

# %% [markdown]
# ## Q1. Data Preprocessing

# %%
nltk.download('punkt')
nltk.download('stopwords')

def preprocess_text(input_text):
    # Lowercase the text
    # print("\nPerforming operation a. Lowercase the text")
    lowercased_text = input_text.lower()
    # print(lowercased_text)

    # Tokenization
    # print("\nPerforming operation b. Perform tokenization")
    tokens = word_tokenize(lowercased_text)
    # print(tokens)

    # Remove stopwords
    # print("\nPerforming operation c. Remove stopwords")
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [token for token in tokens if token not in stop_words]
    # print(filtered_tokens)

    # Remove punctuations
    # print("\nPerforming operation d. Remove punctuations")
    filtered_tokens = [token for token in filtered_tokens if token not in punctuation]
    # print(filtered_tokens)

    # Remove blank space tokens
    # print("\nPerforming operation e. Remove blank space tokens")
    filtered_tokens = [token for token in filtered_tokens if token.strip()]
    # print(filtered_tokens)

    # Join tokens back into a string
    preprocessed_text = ' '.join(filtered_tokens)
    return preprocessed_text

def preprocess_folder(input_folder, output_folder):
    for filename in os.listdir(input_folder):
        if filename.endswith(".txt"):
            file_path = os.path.join(input_folder, filename)
            with open(file_path, 'r', encoding='utf-8') as file:
                original_text = file.read()

            preprocessed_text = preprocess_text(original_text)

            output_file_path = os.path.join(output_folder, filename)
            with open(output_file_path, 'w', encoding='utf-8') as output_file:
                output_file.write(preprocessed_text)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data_path = '/content/drive/MyDrive/IR/A1/text_files'
preprocessed_data_path = '/content/drive/MyDrive/IR/A1/preprocessed_text_files'
# preprocess_folder(data_path, preprocessed_data_path)

# %%
## Print 5 samples
for filename in os.listdir(data_path)[2:7]:
    file_path = os.path.join(data_path, filename)
    with open(file_path, 'r', encoding='utf-8') as file:
        original_text = file.read()
    print(f"\nOriginal content of {filename}:\n{original_text}\n")

    preprocessed_text = preprocess_text(original_text)
    print(f"\nPreprocessed content of {filename}:\n{preprocessed_text}\n")
# Out:
# Original content of file903.txt:
# This guitar is perfect in every way! It's so easy to play and sounds fantastic! Perfectly balanced with zero neck dive. The bomb inlays just look cool! I definitely plan on buying more Hardluck Kings guitars!
#
#
# Performing operation a. Lowercase the text
# this guitar is perfect in every way! it's so easy to play and sounds fantastic! perfectly balanced with zero neck dive. the bomb inlays just look cool! i definitely plan on buying more hardluck kings guitars!
#
# Performing operation b. Perform tokenization
# ['this', 'guitar', 'is', 'perfect', 'in', 'every', 'way', '!', 'it', "'s", 'so', 'easy', 'to', 'play', 'and', 'sounds', 'fantastic', '!', 'perfectly', 'balanced', 'with', 'zero', 'neck', 'dive', '.', 'the', 'bomb', 'inlays', 'just', 'look', 'cool', '!', 'i', 'definitely', 'plan', 'on', 'buying', 'more', 'hardluck', 'kings', 'guitars', '!']
#
# Performing operation c. Remove stopwords
# ['guitar', 'perfect', 'every', 'way', '!', "'s", 'easy', 'play', 'sounds', 'fantastic', '!', 'perfectly', 'balanced', 'zero', 'neck', 'dive', '.', 'bomb', 'inlays', 'look', 'cool', '!', 'definitely', 'plan', 'buying', 'hardluck', 'kings', 'guitars', '!']
#
# Performing operation d. Remove punctuations
# ['guitar', 'perfect', 'every', 'way', "'s", 'easy', 'play', 'sounds', 'fantastic', 'perfectly', 'balanced', 'zero', 'neck', 'dive', 'bomb', 'inlays', 'look', 'cool', 'definitely', 'plan', 'buying', 'hardluck', 'kings', 'guitars']
#
# Performing operation e. Remove blank space tokens
# ['guitar', 'perfect', 'every', 'way', "'s", 'easy', 'play', 'sounds', 'fantastic', 'perfectly', 'balanced', 'zero', 'neck', 'dive', 'bomb', 'inlays', 'look', 'cool', 'definitely', 'plan', 'buying', 'hardluck', 'kings', 'guitars']
#
# Preprocessed content of file903.txt:
# guitar perfect every way 's easy play sounds fantastic perfectly balanced zero neck dive bomb inlays look cool definitely plan buying hardluck kings guitars
#
#
# Original content of file902.txt:
# Beautiful, well-made strap. Matches my guitar nicely. Perfect.
#
#
# Performing operation a. Lowercase the text
# beautiful, well-made strap. matches my guitar nicely. perfect.
#
# Performing operation b. Perform tokenization
# ['beautiful', ',', 'well-made', 'strap', '.', 'matches', 'my', 'guitar', 'nicely', '.', 'perfect', '.']
#
# Performing operation c. Remove stopwords
# ['beautiful', ',', 'well-made', 'strap', '.', 'matches', 'guitar', 'nicely', '.', 'perfect', '.']
#
# Performing operation d. Remove punctuations
# ['beautiful', 'well-made', 'strap', 'matches', 'guitar', 'nicely', 'perfect']
#
# Performing operation e. Remove blank space tokens
# ['beautiful', 'well-made', 'strap', 'matches', 'guitar', 'nicely', 'perfect']
#
# Preprocessed content of file902.txt:
# beautiful well-made strap matches guitar nicely perfect
#
#
# Original content of file199.txt:
# Amazing and highly different Wah from ibanez,This is the WAH YA WANT!!,too many reasons!,Just check it out!!!
#
#
# Performing operation a. Lowercase the text
# amazing and highly different wah from ibanez,this is the wah ya want!!,too many reasons!,just check it out!!!
#
# Performing operation b. Perform tokenization
# ['amazing', 'and', 'highly', 'different', 'wah', 'from', 'ibanez', ',', 'this', 'is', 'the', 'wah', 'ya', 'want', '!', '!', ',', 'too', 'many', 'reasons', '!', ',', 'just', 'check', 'it', 'out', '!', '!', '!']
#
# Performing operation c. Remove stopwords
# ['amazing', 'highly', 'different', 'wah', 'ibanez', ',', 'wah', 'ya', 'want', '!', '!', ',', 'many', 'reasons', '!', ',', 'check', '!', '!', '!']
#
# Performing operation d. Remove punctuations
# ['amazing', 'highly', 'different', 'wah', 'ibanez', 'wah', 'ya', 'want', 'many', 'reasons', 'check']
#
# Performing operation e. Remove blank space tokens
# ['amazing', 'highly', 'different', 'wah', 'ibanez', 'wah', 'ya', 'want', 'many', 'reasons', 'check']
#
# Preprocessed content of file199.txt:
# amazing highly different wah ibanez wah ya want many reasons check
#
#
# Original content of file297.txt:
# The quality is excellent
#
#
# Performing operation a. Lowercase the text
# the quality is excellent
#
# Performing operation b. Perform tokenization
# ['the', 'quality', 'is', 'excellent']
#
# Performing operation c. Remove stopwords
# ['quality', 'excellent']
#
# Performing operation d. Remove punctuations
# ['quality', 'excellent']
#
# Performing operation e. Remove blank space tokens
# ['quality', 'excellent']
#
# Preprocessed content of file297.txt:
# quality excellent
#
#
# Original content of file321.txt:
# Good quality :)  perfect for my office/studio setup!
#
#
# Performing operation a. Lowercase the text
# good quality :)  perfect for my office/studio setup!
#
# Performing operation b. Perform tokenization
# ['good', 'quality', ':', ')', 'perfect', 'for', 'my', 'office/studio', 'setup', '!']
#
# Performing operation c. Remove stopwords
# ['good', 'quality', ':', ')', 'perfect', 'office/studio', 'setup', '!']
#
# Performing operation d. Remove punctuations
# ['good', 'quality', 'perfect', 'office/studio', 'setup']
#
# Performing operation e. Remove blank space tokens
# ['good', 'quality', 'perfect', 'office/studio', 'setup']
#
# Preprocessed content of file321.txt:
# good quality perfect office/studio setup

# %% [markdown]
# ## Q2. Unigram Inverted Index

# %% [markdown]
# Freq of docs in inverted index ??

# %%
def create_inverted_index(input_folder):
    inverted_index = {}

    for filename in os.listdir(input_folder):
        file_path = os.path.join(input_folder, filename)
        with open(file_path, 'r', encoding='utf-8') as file:
            document_text = file.read()

            terms = document_text.split()

            for term in set(terms):
                if term not in inverted_index:
                    inverted_index[term] = [filename]
                else:
                    inverted_index[term].append(filename)

# %%
def print_inverted_index(inverted_index):
    for term, documents in inverted_index.items():
        print(f"{term}: {', '.join(documents)}")

# %%
inverted_index = create_inverted_index(preprocessed_data_path)
output_file_path = "/content/drive/MyDrive/IR/A1/inverted_index.pkl"

# save using pickle
with open(output_file_path, 'wb') as file:
        pickle.dump(inverted_index, file)

# load from pickle
with open(output_file_path, 'rb') as file:
        inverted_index = pickle.load(file)

print_inverted_index(inverted_index)
# Out:
# Streaming output truncated to the last 5000 lines.
# behringer: file444.txt, file29.txt, file855.txt, file755.txt, file597.txt, file306.txt, file629.txt, file637.txt, file794.txt, file545.txt, file510.txt, file807.txt, file938.txt
# lr: file444.txt, file804.txt
# character: file444.txt, file688.txt, file637.txt, file541.txt, file220.txt, file106.txt, file916.txt, file253.txt
# knock: file444.txt, file309.txt, file622.txt, file993.txt, file654.txt, file396.txt, file13.txt, file674.txt
# manual: file444.txt, file870.txt, file270.txt, file703.txt, file523.txt, file575.txt
# bandwidth: file444.txt
# upper: file444.txt
# user: file444.txt, file491.txt, file722.txt, file969.txt, file270.txt, file196.txt, file711.txt
# sweetening: file444.txt
# performs: file444.txt, file307.txt
# applications: file444.txt, file130.txt, file998.txt
# handling: file444.txt
# low: file444.txt, file858.txt, file388.txt, file507.txt, file868.txt, file111.txt, file883.txt, file629.txt, file274.txt, file63.txt, file270.txt, file157.txt, file324.txt, file155.txt, file804.txt, file398.txt, file21.txt, file194.txt, file152.txt, file899.txt, file909.txt, file739.txt, file441.txt, file106.txt, file362.txt, file532.txt, file720.txt, file188.txt, file477.txt, file937.txt, file638.txt, file742.txt, file372.txt, file945.txt
# making: file444.txt, file744.txt, file769.txt, file212.txt, file111.txt, file158.txt, file143.txt, file10.txt, file871.txt, file338.txt, file749.txt, file5.txt, file336.txt, file172.txt, file425.txt, file249.txt
# vintage: file51.txt, file725.txt, file827.txt, file895.txt, file597.txt, file494.txt, file150.txt, file1.txt, file197.txt, file907.txt, file737.txt, file422.txt, file936.txt, file439.txt, file278.txt, file638.txt, file847.txt, file674.txt
# rather: file51.txt, file388.txt, file815.txt, file148.txt, file39.txt, file543.txt, file700.txt, file294.txt, file584.txt, file202.txt, file715.txt, file803.txt, file550.txt, file373.txt, file864.txt, file764.txt, file920.txt, file260.txt, file487.txt
# supplied: file51.txt, file123.txt, file451.txt, file33.txt, file949.txt
# tho: file51.txt, file322.txt, file998.txt, file820.txt
# available: file375.txt, file656.txt, file301.txt, file516.txt, file684.txt, file3.txt, file765.txt, file18.txt, file719.txt, file524.txt, file396.txt, file65.txt, file542.txt
# extra: file375.txt, file148.txt, file670.txt, file101.txt, file839.txt, file118.txt, file383.txt, file386.txt, file259.txt, file900.txt, file906.txt, file103.txt, file980.txt, file994.txt, file353.txt, file863.txt, file132.txt, file946.txt, file552.txt, file742.txt, file888.txt
# eight: file375.txt, file294.txt, file596.txt, file510.txt, file200.txt
# replaces: file375.txt
# synced: file375.txt
# derby: file375.txt
# aside: file375.txt, file68.txt, file107.txt, file742.txt
# background: file375.txt, file865.txt, file274.txt, file269.txt, file102.txt, file133.txt, file510.txt
# orange: file375.txt, file676.txt, file100.txt, file246.txt, file338.txt, file911.txt
# house: file375.txt, file934.txt, file157.txt, file307.txt, file326.txt, file490.txt, file73.txt
# purple: file375.txt, file118.txt, file213.txt, file624.txt, file313.txt, file847.txt, file784.txt
# glows: file375.txt
# reliable: file375.txt, file9.txt, file510.txt, file945.txt, file807.txt
# addition: file375.txt, file388.txt, file184.txt, file765.txt, file906.txt, file191.txt, file220.txt, file569.txt, file252.txt, file627.txt, file448.txt
# chauvet: file375.txt, file956.txt
# nearly: file375.txt, file125.txt, file196.txt, file542.txt
# 15: file375.txt, file45.txt, file440.txt, file248.txt, file898.txt, file720.txt, file708.txt
# kinta: file375.txt, file481.txt
# x: file375.txt, file521.txt, file673.txt, file467.txt, file294.txt, file780.txt, file981.txt, file928.txt, file847.txt
# experience: file375.txt, file245.txt, file859.txt, file835.txt, file935.txt, file716.txt, file213.txt, file290.txt, file443.txt, file621.txt, file132.txt, file343.txt
# fills: file375.txt
# replace: file930.txt, file154.txt, file429.txt, file484.txt, file29.txt, file687.txt, file700.txt, file238.txt, file878.txt, file608.txt, file141.txt, file989.txt, file801.txt, file416.txt, file279.txt, file395.txt, file123.txt, file737.txt, file898.txt, file774.txt, file232.txt, file477.txt, file253.txt
# upon: file930.txt, file325.txt, file629.txt, file324.txt, file107.txt, file932.txt
# altogether: file930.txt, file690.txt
# explain: file930.txt, file859.txt
# slipped: file930.txt, file84.txt, file33.txt
# failed: file930.txt, file17.txt, file874.txt
# carabiner: file930.txt
# serves: file566.txt, file338.txt, file326.txt, file216.txt
# difficult: file566.txt, file333.txt, file165.txt, file878.txt, file694.txt, file824.txt
# dangle: file566.txt
# bcos: file566.txt
# unclip: file566.txt
# shorter: file566.txt, file116.txt, file85.txt, file174.txt
# ruggedness: file466.txt
# body: file466.txt, file64.txt, file859.txt, file927.txt, file691.txt, file855.txt, file564.txt, file150.txt, file915.txt, file241.txt, file173.txt, file787.txt, file361.txt, file353.txt, file986.txt, file138.txt, file279.txt, file805.txt, file998.txt, file312.txt, file465.txt, file965.txt, file627.txt, file881.txt, file382.txt, file432.txt, file156.txt, file503.txt
# rim: file466.txt, file991.txt
# assembly: file466.txt, file326.txt
# rests: file466.txt
# paris: file466.txt, file789.txt
# viola: file466.txt
# particular: file466.txt, file64.txt, file849.txt, file340.txt, file438.txt, file789.txt, file77.txt, file308.txt, file344.txt, file788.txt, file603.txt
# nominally: file466.txt
# frame: file466.txt, file684.txt, file10.txt, file849.txt, file352.txt
# length: file466.txt, file672.txt, file118.txt, file294.txt, file597.txt, file849.txt, file187.txt, file994.txt, file132.txt, file998.txt, file719.txt, file588.txt, file232.txt, file949.txt
# irish: file466.txt, file489.txt
# bodhran: file466.txt
# 18: file466.txt, file491.txt, file611.txt, file160.txt, file627.txt, file542.txt
# hercules: file466.txt, file42.txt, file382.txt
# bonus: file466.txt, file860.txt, file174.txt
# comfortably: file466.txt, file745.txt, file449.txt
# stringed: file466.txt, file490.txt
# auto: file466.txt, file39.txt, file882.txt, file147.txt, file542.txt, file218.txt
# swing: file466.txt, file279.txt
# subwoofer: file706.txt, file248.txt, file708.txt
# rounds: file706.txt
# woofer: file706.txt, file248.txt
# yard: file706.txt, file394.txt
# cases: file706.txt, file363.txt, file148.txt, file560.txt, file404.txt, file746.txt, file311.txt, file397.txt
# kudos: file706.txt
# prime: file706.txt, file770.txt, file234.txt, file733.txt, file742.txt
# whoever: file706.txt, file177.txt
# doorstep: file706.txt
# kicks: file706.txt, file322.txt
# packages: file706.txt, file112.txt
# butt: file706.txt, file322.txt, file476.txt
# thumping: file706.txt
# damaged: file706.txt, file363.txt, file676.txt, file746.txt, file155.txt, file176.txt, file698.txt, file73.txt, file365.txt
# packaged: file706.txt, file512.txt, file586.txt, file251.txt, file674.txt, file728.txt
# package: file706.txt, file79.txt, file226.txt, file915.txt, file247.txt, file371.txt, file550.txt, file990.txt, file681.txt, file334.txt, file267.txt, file268.txt, file219.txt, file313.txt, file439.txt, file742.txt, file949.txt
# styrofoam: file706.txt, file559.txt
# sheriff: file706.txt
# audiosavings: file706.txt
# ship: file706.txt
# inner: file706.txt, file733.txt, file371.txt
# sub: file706.txt, file409.txt
# rockville: file706.txt
# exception: file706.txt, file412.txt
# damage: file706.txt, file884.txt, file150.txt, file226.txt, file18.txt, file30.txt, file440.txt, file698.txt, file224.txt
# ended: file706.txt, file516.txt, file632.txt, file895.txt, file617.txt, file23.txt
# floored: file706.txt
# decide: file612.txt, file534.txt
# sentimental: file612.txt, file490.txt
# colored: file612.txt, file148.txt, file457.txt, file606.txt, file265.txt
# epiphone: file612.txt, file180.txt, file62.txt, file859.txt, file54.txt, file38.txt, file164.txt, file221.txt, file606.txt, file400.txt, file886.txt, file754.txt, file541.txt, file312.txt, file107.txt, file774.txt, file756.txt, file412.txt, file265.txt, file982.txt
# cream: file612.txt, file855.txt, file606.txt, file915.txt, file737.txt, file265.txt
# trim: file612.txt, file606.txt, file292.txt, file791.txt, file153.txt, file882.txt, file542.txt, file265.txt
# beginner: file612.txt, file64.txt, file202.txt, file214.txt, file621.txt, file872.txt, file5.txt, file788.txt, file991.txt
# poker: file612.txt
# chip: file612.txt, file133.txt, file920.txt, file847.txt
# upgrading: file612.txt, file184.txt, file469.txt, file343.txt
# rid: file612.txt, file668.txt, file804.txt
# swapped: file612.txt, file606.txt, file494.txt, file265.txt
# classic: file154.txt, file64.txt, file883.txt, file461.txt, file322.txt, file626.txt, file843.txt, file781.txt, file609.txt, file422.txt, file712.txt, file617.txt, file653.txt, file413.txt, file921.txt
# bunch: file154.txt, file80.txt, file714.txt, file660.txt
# aging: file154.txt
# items: file154.txt, file835.txt, file701.txt, file550.txt, file536.txt, file447.txt, file654.txt, file932.txt
# surprises: file154.txt
# critical: file154.txt, file214.txt
# band: file154.txt, file24.txt, file29.txt, file901.txt, file78.txt, file228.txt, file400.txt, file968.txt, file187.txt, file987.txt, file357.txt, file959.txt, file977.txt, file460.txt, file844.txt
# manage: file154.txt, file959.txt
# mics: file154.txt, file78.txt, file855.txt, file975.txt, file871.txt, file573.txt, file460.txt, file844.txt, file308.txt, file448.txt, file574.txt, file891.txt, file949.txt
# gear: file154.txt, file729.txt, file673.txt, file910.txt, file883.txt, file27.txt, file307.txt, file501.txt, file160.txt, file542.txt
# interest: file154.txt
# exactly: file154.txt, file363.txt, file19.txt, file121.txt, file169.txt, file822.txt, file221.txt, file98.txt, file626.txt, file726.txt, file263.txt, file203.txt, file268.txt, file957.txt, file397.txt, file490.txt, file126.txt
# applying: file154.txt
# fwiw: file154.txt
# taking: file154.txt, file521.txt, file686.txt, file934.txt, file202.txt, file889.txt, file718.txt, file438.txt, file885.txt, file268.txt, file454.txt, file435.txt, file446.txt, file709.txt
# snakes: file154.txt
# turbo: file668.txt
# awsome: file668.txt, file213.txt
# voodo: file668.txt
# combo: file668.txt, file883.txt, file349.txt, file847.txt, file813.txt
# man: file668.txt, file650.txt, file620.txt, file896.txt, file781.txt, file314.txt, file951.txt, file758.txt, file490.txt, file554.txt
# gain: file668.txt, file100.txt, file786.txt, file794.txt, file852.txt, file441.txt, file847.txt
# told: file668.txt, file363.txt, file148.txt, file469.txt, file157.txt, file524.txt, file813.txt
# mean: file668.txt, file78.txt, file514.txt, file176.txt
# skull: file668.txt
# compressor: file668.txt, file220.txt
# screamers: file668.txt, file336.txt
# ripping: file668.txt
# rat: file668.txt, file434.txt, file441.txt
# late: file125.txt, file554.txt
# the: file125.txt, file24.txt, file567.txt, file608.txt, file269.txt, file102.txt, file703.txt, file490.txt
# dandies: file125.txt
# cancel: file125.txt
# perfection: file125.txt, file413.txt
# flatish: file125.txt
# competitors: file125.txt, file563.txt
# disappear: file125.txt
# causing: file125.txt, file884.txt, file150.txt, file379.txt
# detailed: file125.txt
# drawings: file125.txt
# satiny: file125.txt
# countersink: file125.txt
# fairly: file859.txt, file676.txt, file762.txt, file884.txt, file418.txt, file349.txt, file263.txt, file156.txt, file780.txt, file412.txt
# response: file859.txt, file815.txt, file507.txt, file184.txt, file292.txt, file870.txt, file843.txt, file637.txt, file43.txt, file248.txt
# differently: file859.txt, file360.txt
# later: file859.txt, file910.txt, file443.txt, file558.txt, file303.txt, file252.txt, file328.txt, file468.txt, file593.txt
# silks: file859.txt
# before: file859.txt
# across: file859.txt, file201.txt, file292.txt, file777.txt, file157.txt, file749.txt, file308.txt
# til: file859.txt, file782.txt
# marketed: file163.txt
# buck: file163.txt, file519.txt, file899.txt
# bring: file163.txt
# tonight: file163.txt, file813.txt
# originals: file163.txt, file422.txt
# surely: file163.txt, file24.txt
# boutique: file163.txt, file191.txt, file413.txt
# slowly: file163.txt, file691.txt, file604.txt, file817.txt
# korean: file163.txt, file96.txt
# marched: file163.txt
# squire: file163.txt, file519.txt, file383.txt, file733.txt, file801.txt, file853.txt, file907.txt, file422.txt, file159.txt
# learning: file163.txt, file927.txt, file29.txt, file620.txt, file741.txt, file991.txt, file817.txt, file265.txt
# roaring: file163.txt
# wow: file163.txt, file419.txt, file839.txt, file256.txt, file100.txt, file576.txt, file48.txt, file520.txt, file911.txt, file702.txt, file851.txt, file775.txt, file510.txt
# wonder: file163.txt, file674.txt
# replacing: file163.txt, file355.txt, file604.txt
# life: file163.txt, file769.txt, file610.txt, file549.txt, file399.txt, file98.txt, file37.txt, file277.txt, file550.txt, file194.txt, file339.txt, file874.txt, file824.txt, file711.txt, file52.txt
# bang: file163.txt, file519.txt, file663.txt, file593.txt
# laying: file163.txt, file475.txt
# covered: file163.txt, file290.txt, file157.txt, file637.txt, file640.txt, file542.txt
# trees: file547.txt, file893.txt, file579.txt, file420.txt
# elbow: file547.txt
# screwed: file547.txt, file301.txt, file440.txt, file764.txt, file617.txt
# peavey: file547.txt, file831.txt, file420.txt, file574.txt
# tree: file547.txt, file273.txt, file985.txt, file420.txt
# grease: file547.txt
# ...
# simultaneous: file308.txt
# choosing: file308.txt
# vocalists: file308.txt
# diaphragm: file308.txt
# djmaximo: file866.txt
# aids: file866.txt
# fidelity: file866.txt
# fascinated: file866.txt
# hd: file866.txt
# nashville: file327.txt
# tn: file327.txt
# repair: file327.txt
# dab: file774.txt
# definite: file774.txt
# filed: file774.txt
# p90: file774.txt, file412.txt
# ponys: file836.txt
# gamble: file836.txt
# vu: file362.txt
# ddj: file362.txt
# velocity: file362.txt
# whisp: file362.txt
# triggers: file362.txt
# filters: file362.txt
# ruined: file532.txt
# volumes: file532.txt
# blow: file532.txt
# event: file532.txt
# smoking: file532.txt
# vote: file409.txt
# frameworks: file409.txt
# indestructible: file409.txt
# mos: file409.txt
# poles: file409.txt
# gabf: file409.txt
# stylish: file409.txt
# denver: file409.txt
# festival: file409.txt
# psm1: file651.txt
# procaster: file651.txt
# shockmount: file651.txt, file33.txt
# dread: file780.txt
# 36: file780.txt
# parlor: file780.txt
# wammy: file806.txt
# pill: file861.txt
# recoil: file861.txt
# cavities: file861.txt, file937.txt
# accepted: file861.txt
# latest: file861.txt
# formed: file861.txt
# crooked: file159.txt, file352.txt
# recommending: file159.txt
# lip: file159.txt
# thrifty: file159.txt
# guessed: file159.txt
# intonate: file159.txt
# vm: file159.txt
# pale: file159.txt
# slot: file159.txt, file953.txt
# guitarists: file159.txt, file352.txt
# prices: file396.txt
# legitimate: file396.txt
# homemade: file396.txt
# cbg: file396.txt
# smearing: file396.txt
# commercial: file396.txt
# scream: file396.txt
# 1gap: file802.txt
# favourite: file313.txt
# ziplock: file313.txt
# throaty: file936.txt
# kazoo: file936.txt
# 66: file936.txt
# 59: file936.txt, file176.txt
# 63: file936.txt
# heaven: file936.txt, file413.txt
# cray: file936.txt
# specials: file936.txt
# spoiled: file936.txt
# 250: file936.txt
# thud: file936.txt
# borrow: file983.txt
# insulated: file75.txt
# virtual: file981.txt
# 2110: file981.txt
# with: file981.txt
# gk: file981.txt
# miniak: file981.txt
# synthesizer: file981.txt
# rc: file981.txt
# b005p4nvji: file981.txt
# viewing: file981.txt
# b002maaw4u: file981.txt
# akai: file981.txt
# vocoder: file981.txt
# released: file232.txt
# fastening: file232.txt
# phophorus: file288.txt
# thinline: file882.txt
# barbell: file882.txt
# sharpened: file882.txt
# turners: file882.txt
# whiteside: file882.txt
# scrollsaw: file882.txt
# manufacture: file882.txt
# sided: file882.txt
# routing: file882.txt
# blade: file882.txt, file33.txt
# router: file882.txt
# spiral: file882.txt
# mdf: file882.txt
# slash: file882.txt
# partscasters: file882.txt
# valley: file821.txt
# finding: file821.txt, file405.txt
# curvature: file821.txt
# edged: file821.txt
# rounded: file821.txt
# vine: file633.txt
# luthier: file633.txt
# dad: file633.txt
# program: file633.txt
# banjo: file633.txt, file813.txt, file603.txt
# fancy: file633.txt, file490.txt
# scroll: file633.txt
# trial: file633.txt
# regarded: file359.txt
# dictate: file359.txt
# begin: file359.txt
# marvelously: file344.txt
# refer: file344.txt
# muffling: file344.txt
# windy: file344.txt
# h1n: file344.txt
# chinchilla: file344.txt
# elastic: file344.txt, file249.txt
# mooer: file775.txt
# tender: file775.txt
# acrylic: file775.txt
# octaver: file775.txt
# contender: file775.txt
# wowwwy: file775.txt
# silly: file775.txt
# morpher: file775.txt
# affect: file720.txt
# protractor: file720.txt
# pine: file720.txt
# inconsistencies: file720.txt
# 10mins: file243.txt
# falloff: file951.txt
# nano: file951.txt
# burning: file951.txt
# oit: file15.txt
# inherent: file222.txt
# blush: file222.txt
# flaw: file222.txt, file904.txt
# integrity: file222.txt
# 02: file222.txt
# trips: file222.txt
# ac: file222.txt
# prong: file222.txt
# outlets: file222.txt
# jp: file222.txt
# united: file222.txt
# readers: file222.txt
# rectangles: file928.txt
# amazingly: file928.txt, file593.txt
# soap: file928.txt, file264.txt
# approximately: file928.txt
# grocery: file928.txt
# sink: file928.txt
# dish: file928.txt
# gummi: file928.txt
# b0019iaz3y: file928.txt
# greedy: file114.txt
# private: file114.txt
# promised: file114.txt
# retainer: file617.txt
# electrosockets: file617.txt
# mmx: file809.txt
# xmas: file752.txt
# scerouse: file752.txt
# horn: file752.txt, file352.txt
# students: file752.txt
# cleanst: file752.txt
# wannted: file752.txt
# scent: file752.txt
# ligatures: file752.txt
# 808: file336.txt
# transparent: file336.txt
# clones: file336.txt
# modded: file336.txt, file916.txt
# river: file336.txt
# ts9dx: file336.txt
# harmonix: file336.txt
# od808: file336.txt
# electro: file336.txt
# maxon: file336.txt
# reissue: file336.txt, file653.txt
# ts808: file336.txt
# smoother: file336.txt, file562.txt
# overdriven: file336.txt
# stompswitch: file336.txt
# favorites: file336.txt
# ts9: file336.txt
# blanket: file336.txt
# presentation: file139.txt
# miniature: file216.txt
# regretted: file216.txt
# festive: file216.txt
# tub: file216.txt
# campfires: file216.txt
# dropbox: file468.txt
# powerpoint: file468.txt
# stunned: file468.txt
# ppt: file468.txt
# youmic: file468.txt
# bigsby: file176.txt, file554.txt
# bux: file176.txt
# runner: file176.txt
# noticable: file176.txt
# useage: file875.txt
# frequently: file875.txt, file920.txt, file11.txt
# newest: file875.txt
# general: file875.txt
# specifically: file875.txt, file174.txt
# fastest: file875.txt, file945.txt
# buckled: file875.txt
# liner: file124.txt
# 15w: file124.txt
# drillbit: file985.txt
# ruler: file985.txt
# cts: file58.txt
# loosely: file867.txt
# identify: file867.txt
# challenged: file867.txt
# mechanically: file867.txt
# thanx: file583.txt, file413.txt
# prefect: file583.txt
# newer: file920.txt
# piss: file920.txt, file992.txt
# tandem: file920.txt
# lm308: file920.txt
# clockwise: file920.txt
# coveted: file920.txt
# lsr305: file172.txt
# 650b: file172.txt
# pointed: file172.txt
# lowering: file172.txt
# dgx: file172.txt
# jbl: file172.txt
# resistor: file439.txt
# cleanest: file439.txt
# brightest: file439.txt
# gritty: file439.txt
# capacitors: file439.txt
# updated: file439.txt
# cranking: file235.txt
# sea: file235.txt
# rendering: file235.txt
# hrs: file235.txt
# tmb100: file235.txt
# tldr: file235.txt
# terrified: file235.txt
# configuration: file235.txt
# traded: file235.txt
# resistant: file144.txt
# goodies: file144.txt
# harmonica: file144.txt, file660.txt, file788.txt
# waking: file144.txt
# neighborhood: file144.txt
# uninstalled: file272.txt
# defeinitely: file272.txt
# nan: file829.txt
# fxii: file711.txt
# loowood2: file711.txt
# axe: file711.txt
# dash: file711.txt
# loowood: file711.txt
# fractal: file711.txt
# google: file711.txt
# eleven: file711.txt
# internals: file367.txt
# died: file367.txt
# supplie: file367.txt
# scientist: file367.txt
# afterwards: file367.txt
# emad2: file758.txt
# dancing: file758.txt
# catalina: file758.txt
# cannon: file758.txt
# churchs: file758.txt
# hitter: file758.txt
# mother: file280.txt
# chart: file280.txt
# recieved: file280.txt, file240.txt, file797.txt
# hooks: file490.txt
# sword: file490.txt
# engineering: file490.txt
# her: file490.txt
# cave: file490.txt
# phd: file490.txt
# virginia: file490.txt
# b00cbrtq1o: file490.txt
# fir: file946.txt
# ankle: file946.txt
# bells: file946.txt
# pleasant: file946.txt, file188.txt, file11.txt
# tempted: file510.txt, file728.txt
# originates: file510.txt
# derives: file510.txt
# rivet: file200.txt
# abs: file200.txt
# bore: file200.txt
# burly: file200.txt
# moly: file200.txt
# bronco: file916.txt
# flare: file916.txt
# indicating: file698.txt
# surrounding: file698.txt, file448.txt
# occured: file698.txt
# cough: file660.txt
# diatonic: file660.txt
# harps: file660.txt
# lee: file660.txt
# harmonicas: file660.txt
# throatier: file660.txt
# madman: file660.txt
# oskar: file660.txt
# lung: file660.txt
# reed: file660.txt
# excess: file660.txt
# playablity: file660.txt
# durabilty: file660.txt
# b1hpwitr57s: file105.txt
# 2000s: file105.txt
# disclaimer: file105.txt, file425.txt
# ier: file105.txt
# r21fu14f1rfdce: file105.txt
# a1vfa9m6was: file105.txt
# 400ce: file562.txt
# sensual: file310.txt
# angels: file310.txt
# des: file653.txt
# 1960: file653.txt
# focused: file188.txt
# extreme: file188.txt
# bearing: file188.txt
# brutality: file188.txt
# usefull: file23.txt
# fretwraps: file23.txt
# slapping: file23.txt
# invest: file82.txt, file736.txt
# yas: file82.txt
# sooo: file82.txt
# microponic: file284.txt
# driven: file284.txt
# ceilings: file663.txt
# rihekjf1laqw9: file663.txt
# dates: file663.txt
# april: file663.txt
# 910xywt631s: file663.txt
# c1t: file663.txt
# chase: file663.txt
# housed: file663.txt, file847.txt
# parties: file663.txt
# tops: file663.txt
# 2buzzlt8s: file663.txt
# squinters: file663.txt
# dance: file663.txt
# valvey: file413.txt
# 6000: file413.txt
# wailing: file413.txt
# accordion: file413.txt
# 82: file413.txt
# pignose: file413.txt
# micand: file413.txt
# 30hog: file413.txt
# superlux: file413.txt
# punches: file413.txt
# legendary: file413.txt
# repeated: file239.txt
# knowvthat: file239.txt
# unload: file239.txt
# 7pm: file239.txt
# jackson: file477.txt
# trems: file477.txt
# rr3: file477.txt
# holeyboard: file760.txt
# bug: file760.txt
# onespot: file760.txt
# quieter: file760.txt
# alter: file760.txt
# powering: file760.txt
# ego: file760.txt
# newbie: file788.txt
# skilled: file788.txt
# exercises: file788.txt
# protects: file892.txt
# reducing: file581.txt
# omcpa4: file581.txt
# beefier: file65.txt
# tiered: file65.txt
# gaia: file65.txt
# 2011: file345.txt
# tighly: file33.txt
# v67g: file33.txt
# resemblance: file33.txt
# 890: file33.txt
# porch: file33.txt
# bears: file33.txt
# striking: file33.txt
# stamps: file750.txt
# unfamiliar: file750.txt
# proud: file283.txt
# ryan: file530.txt
# ron: file530.txt
# skme: file530.txt
# signed: file87.txt
# jus: file87.txt
# ej: file87.txt
# vesa: file953.txt
# equivalent: file953.txt
# mikes: file953.txt
# lays: file845.txt
# warmoth: file11.txt
# highlight: file11.txt
# bolted: file11.txt
# builds: file11.txt
# pudding: file11.txt
# stain: file11.txt
# counterweight: file44.txt
# maneuver: file44.txt
# teenager: file552.txt
# sufficient: file264.txt
# lavender: file264.txt
# 400w: file264.txt
# pronounced: file264.txt
# mist: file264.txt
# moody: file264.txt
# visibility: file264.txt
# fluid: file264.txt
# odor: file264.txt
# rise: file264.txt, file813.txt
# bursts: file264.txt
# dense: file264.txt
# linger: file264.txt
# fireball: file260.txt
# coats: file260.txt, file253.txt
# clorox: file260.txt
# wipes: file260.txt
# unusual: file260.txt
# touched: file260.txt
# agp: file55.txt
# excuse: file55.txt
# illumination: file55.txt
# strewn: file55.txt
# inserts: file366.txt
# inspired: file571.txt
# mij: file571.txt
# incredibly: file425.txt
# ideas: file425.txt
# guiar: file593.txt
# sparkly: file593.txt
# falsely: file593.txt
# puckguard: file593.txt
# chisel: file937.txt
# epoxy: file937.txt
# h6: file500.txt
# relation: file500.txt
# trs: file808.txt, file938.txt
# lyxpro: file808.txt
# silicone: file808.txt
# shortened: file808.txt
# neutrix: file808.txt
# neutric: file808.txt
# seismic: file808.txt
# jacket: file808.txt
# 320: file240.txt
# enter: file240.txt
# voiceover: file240.txt
# re20: file240.txt
# backyard: file147.txt
# degrees: file147.txt
# ditto: file904.txt
# looper: file904.txt
# arturia: file942.txt
# microbrute: file942.txt
# synth: file942.txt
# each: file756.txt
# hbs: file756.txt
# driving: file174.txt
# metro: file174.txt
# 0991622206: file174.txt
# plane: file174.txt
# starcaster: file174.txt
# confirm: file174.txt
# cosmetically: file302.txt
# balances: file302.txt
# badass: file967.txt
# pentagrams: file967.txt
# mods: file278.txt
# ps: file278.txt
# buster: file278.txt
# themed: file86.txt
# steeler: file86.txt
# upwards: file414.txt
# ma: file414.txt
# barrel: file414.txt
# 1986: file420.txt
# drowns: file638.txt
# 69s: file638.txt
# 62s: file638.txt
# 54s: file638.txt
# 50s: file638.txt
# harmonics: file638.txt
# quacky: file638.txt
# quack: file638.txt
# 1s: file638.txt
# strike: file638.txt
# chimey: file638.txt
# powers: file638.txt
# coils: file638.txt
# ness: file638.txt
# aaa: file347.txt
# earbuds: file347.txt
# deliveres: file347.txt
# baught: file347.txt
# buds: file347.txt
# us90: file347.txt
# uiisii: file347.txt
# evening: file347.txt
# plastc: file347.txt
# lithium: file347.txt, file742.txt
# bangs: file73.txt
# cherish: file73.txt
# unplugging: file533.txt
# senses: file374.txt
# settle: file374.txt
# enclosed: file742.txt
# tm50bk: file742.txt
# mugig: file742.txt
# donate: file742.txt
# lying: file742.txt
# assumption: file742.txt
# musedo: file742.txt
# co2crea: file742.txt
# logos: file742.txt
# member: file742.txt
# b01f8imxvc: file742.txt
# spindle: file448.txt
# branded: file448.txt, file372.txt
# jealous: file448.txt
# mutch: file771.txt
# injection: file992.txt
# fed: file992.txt
# purists: file992.txt
# saddles: file992.txt
# graph: file992.txt
# import: file992.txt, file674.txt
# graphite: file992.txt
# mold: file992.txt
# believer: file992.txt
# pazaz: file708.txt
# unison: file708.txt
# flashing: file708.txt
# dimmed: file708.txt
# lx: file708.txt
# flashes: file708.txt
# dubstep: file708.txt
# climb: file708.txt
# alternated: file708.txt
# restocking: file708.txt
# flashed: file708.txt
# integrated: file372.txt
# shoppers: file372.txt
# inform: file372.txt
# branding: file372.txt
# strongly: file131.txt
# ex: file13.txt
# angry: file13.txt
# seymour: file13.txt
# awake: file13.txt
# prolong: file52.txt
# thickest: file52.txt
# aquarian: file52.txt
# junior: file412.txt
# belie: file412.txt
# forum: file412.txt
# fifty: file412.txt, file913.txt
# epis: file412.txt
# rite: file888.txt
# perpose: file991.txt
# clutter: file119.txt
# hihat: file119.txt
# c8r4: file847.txt
# cabinet: file847.txt
# british: file847.txt
# jensen: file847.txt
# legacy: file847.txt
# setups: file847.txt
# invasion: file847.txt
# hotone: file847.txt
# picksp: file352.txt
# fiber: file352.txt
# grips: file352.txt
# demand: file352.txt
# frames: file352.txt
# bassists: file352.txt
# necessity: file352.txt
# accurately: file945.txt
# repeatedly: file945.txt
# smashing: file921.txt
# webcam: file913.txt
# 818wjxexxds: file913.txt
# r1a2t6z40s0pcw: file913.txt
# ideal: file913.txt
# heaps: file913.txt
# weighty: file913.txt
# c12pr9hxo: file913.txt
# variable: file253.txt
# rolling: file253.txt
# workshop: file253.txt
# judging: file253.txt
# tung: file253.txt
# handmade: file253.txt
# drawer: file735.txt, file728.txt
# competition: file389.txt
# quasi: file813.txt
# invited: file813.txt
# race: file813.txt
# dixieland: file813.txt
# di: file813.txt
# xt65r: file813.txt
# photographs: file813.txt
# creek: file813.txt
# wrap: file542.txt
# putty: file542.txt
# ar420: file542.txt
# moog: file570.txt
# pv: file574.txt
# awesomely: file574.txt
# messing: file343.txt
# cross: file343.txt
# courses: file343.txt
# 1000: file343.txt
# captivated: file343.txt
# haul: file343.txt
# lisa: file343.txt
# mixtrack: file343.txt
# mona: file343.txt
# numark: file343.txt
# hobbyist: file343.txt
# whenever: file126.txt
# began: file126.txt
# drove: file126.txt
# avid: file126.txt
# tubes: file487.txt
# submitted: file487.txt
# jaw: file603.txt
# transposing: file603.txt
# importance: file603.txt, file938.txt
# moveable: file603.txt
# ukuleleists: file603.txt
# advantage: file603.txt
# hernally: file603.txt
# shift: file603.txt
# truthfully: file603.txt
# dealing: file603.txt
# sm57: file891.txt
# booth: file784.txt
# odyssey: file109.txt
# mastered: file304.txt
# striker: file304.txt
# pillow: file304.txt
# thumbs: file817.txt
# dances: file817.txt
# gladly: file817.txt
# raises: file817.txt
# c5: file316.txt
# irc: file218.txt
# gigbar: file218.txt
# programs: file218.txt
# 4bar: file218.txt
# menu: file218.txt
# utilize: file709.txt
# pr40: file709.txt
# heil: file709.txt
# diid: file674.txt
# gfs: file674.txt
# 190: file674.txt
# xaviere: file674.txt
# exceptionally: file674.txt
# magnetic: file674.txt
# arte: file736.txt
# drunkard: file736.txt
# weaken: file736.txt
# fiddle: file736.txt
# nearsighted: file736.txt
# ovangkol: file503.txt
# messy: file503.txt
# minis: file503.txt
# dings: file503.txt
# looped: file841.txt
# sooner: file405.txt
# blend: file405.txt
# tiger: file405.txt
# velcros: file956.txt
# paperwork: file956.txt
# misc: file956.txt
# slimpar: file956.txt
# rgba: file956.txt
# tools: file249.txt
# flashlight: file249.txt
# puller: file249.txt
# wrenches: file249.txt
# winder: file249.txt
# unprepared: file249.txt
# poking: file249.txt
# mate: file249.txt
# prodding: file249.txt
# subject: file249.txt
# tonecapacitor: file797.txt
# anouncement: file797.txt
# emerson: file797.txt
# royale: file265.txt
# newb: file265.txt
# riff: file554.txt
# delivry: file554.txt
# detuning: file554.txt
# jet: file554.txt
# punched: file728.txt
# random: file728.txt
# bummed: file728.txt
# baritones: file949.txt
# b0002gxumw: file949.txt
# dmk: file949.txt
# attachment: file949.txt
# b0002zo3lk: file949.txt
# nady: file949.txt
# steadily: file949.txt
# dm70: file949.txt
# dm80: file949.txt
# saxophones: file949.txt
# b00080f7cs: file949.txt
# assemblies: file949.txt
# b0002czqoq: file949.txt
# my550: file949.txt
# gimmit: file740.txt
# macbook: file938.txt
# sales: file938.txt
# winter: file938.txt

# %%
def execute_query(query, inverted_index):
    # Split the query into terms and operations
    query_parts = query.split()

    all_documents = set(os.listdir(preprocessed_data_path))
    result_documents = set(inverted_index.get(query_parts[0]))

    i = 1
    while i < len(query_parts):

        term = query_parts[i]

        if term == "AND":
            if (i < len(query_parts) - 1) and query_parts[i+1] == "NOT":
                result_documents = result_documents.difference(inverted_index.get(query_parts[i+2], set()))
                i = i+3
            else:
                result_documents = result_documents.intersection(inverted_index.get(query_parts[i+1], set()))
                i = i+2

        elif term == "OR":
            if (i < len(query_parts) - 1) and query_parts[i+1] == "NOT":
                result_documents = result_documents.union(set(all_documents).difference(inverted_index.get(query_parts[i+2], set())))
                i = i+3
            else:
                result_documents = result_documents.union(inverted_index.get(query_parts[i+1], set()))
                i = i+2

    return list(result_documents)

# %%
inverted_index_path = "/content/drive/MyDrive/IR/A1/inverted_index.pkl"

with open(inverted_index_path, 'rb') as file:
        inverted_index = pickle.load(file)

N = int(input())

for i in range(N):
    input_sequence = input().strip()
    operations = input().split(', ')

    # Preprocess the input sequence
    preprocessed_input = preprocess_text(input_sequence)
    preprocessed_input__ = preprocessed_input.split()
    query = ""
    for item1, item2 in zip(preprocessed_input__, operations):
        query += str(item1) + " " + str(item2) + " "

    # Add the last element of the first list
    query += str(preprocessed_input__[-1])

    # Execute the query
    result_documents = execute_query(query, inverted_index)

    # Print the output
    print("\nQuery:", query)
    print("Number of documents retrieved:" , len(result_documents))
    print("Names of the documents retrieved", result_documents)
    print()
# Out:
# 2
# Car bag in a canister
# OR, AND NOT
#
# Query: car OR bag AND NOT canister
# Number of documents retrieved: 31
# Names of the documents retrieved ['file780.txt', 'file404.txt', 'file942.txt', 'file864.txt', 'file264.txt', 'file459.txt', 'file892.txt', 'file313.txt', 'file542.txt', 'file860.txt', 'file863.txt', 'file686.txt', 'file174.txt', 'file665.txt', 'file363.txt', 'file682.txt', 'file118.txt', 'file466.txt', 'file573.txt', 'file698.txt', 'file73.txt', 'file981.txt', 'file166.txt', 'file699.txt', 'file956.txt', 'file930.txt', 'file886.txt', 'file797.txt', 'file746.txt', 'file738.txt', 'file3.txt']
#
# Coffee brewing techniques in cookbook
# AND, OR NOT, OR
#
# Query: coffee AND brewing OR NOT techniques OR cookbook
# Number of documents retrieved: 999
.txt', 'file147.txt', 'file438.txt', 'file547.txt', 'file246.txt', 'file646.txt', 'file207.txt', 'file955.txt', 'file932.txt', 'file847.txt', 'file236.txt', 'file814.txt', 'file884.txt', 'file251.txt', 'file178.txt', 'file924.txt', 'file83.txt', 'file305.txt', 'file898.txt', 'file556.txt', 'file949.txt', 'file245.txt', 'file564.txt', 'file252.txt', 'file158.txt', 'file960.txt', 'file910.txt', 'file167.txt', 'file823.txt', 'file366.txt', 'file695.txt', 'file535.txt', 'file623.txt', 'file470.txt', 'file788.txt', 'file724.txt', 'file8.txt', 'file455.txt', 'file55.txt', 'file728.txt', 'file761.txt', 'file691.txt', 'file796.txt', 'file596.txt', 'file155.txt', 'file919.txt', 'file279.txt', 'file298.txt', 'file137.txt', 'file41.txt', 'file135.txt', 'file140.txt', 'file854.txt', 'file887.txt', 'file726.txt', 'file399.txt', 'file248.txt', 'file122.txt', 'file11.txt', 'file538.txt', 'file417.txt', 'file574.txt', 'file227.txt', 'file573.txt', 'file539.txt', 'file629.txt', 'file615.txt', 'file210.txt', 'file782.txt', 'file644.txt', 'file701.txt', 'file876.txt', 'file592.txt', 'file129.txt', 'file406 ...

# %% [markdown]
# ## Q3. Positional Index and Phrase Queries

# %%
def create_positional_index(input_folder):
    positional_index = {}

    for filename in os.listdir(input_folder):
        file_path = os.path.join(input_folder, filename)
        with open(file_path, 'r', encoding='utf-8') as file:
            document_text = file.read()

            terms = document_text.split()
            position = 0  # Position counter for each term in the document

            for term in terms:
                position += 1
                if term not in positional_index:
                    positional_index[term] = {filename: [position]}
                else:
                    if filename not in positional_index[term]:
                        positional_index[term][filename] = [position]
                    else:
                        positional_index[term][filename].append(position)

    return positional_index

# %%
positional_index = create_positional_index(preprocessed_data_path)

# %%
output_file_path = "/content/drive/MyDrive/IR/A1/positional_index.pkl"

# %%
with open(output_file_path, 'wb') as file:
        pickle.dump(positional_index, file)

# %%
with open(output_file_path, 'rb') as file:
        positional_index = pickle.load(file)

# %%
def phrase_query(positional_index, phrase):
    phrase_terms = phrase.split()

    if len(phrase_terms) < 1:
        return []

    potential_documents = set(positional_index.get(phrase_terms[0], set()))

    for term in phrase_terms[1:]:
        potential_documents = potential_documents.intersection(set(positional_index.get(term, set())))

    final_documents = set()
    flag = True

    for document in list(potential_documents):
        positions = positional_index[phrase_terms[0]][document]
        for term in phrase_terms[1:]:
            flag = False
            for pos in positional_index[term][document]:
                if (pos - 1) in positions:
                    flag = True
                    continue
            positions = positional_index[term][document]
        if flag:
            final_documents.add(document)

    return list(final_documents)

# %%
N = int(input())
print()
for i in range(N):
    phrase = preprocess_text(input())

    matching_documents = phrase_query(positional_index, phrase)

    print("\nNumber of documents retrieved for the phrase '{}' using positional index:".format(phrase), len(matching_documents))
    print("Names of documents retrieved for the phrase '{}' using positional index:".format(phrase), sorted(matching_documents))
    print()
# Out:
# 1
#
# happiness is a pain
#
# Number of documents retrieved for the phrase 'happiness pain' using positional index: 0
# Names of documents retrieved for the phrase 'happiness pain' using positional index: []
